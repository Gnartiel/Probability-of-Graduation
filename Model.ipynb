# %% [markdown]
# # Load dataset

# %%
# file data sau khi add bảng diem_Thu
import gdown
# !gdown 1fIabyDsMHzYnpOR1AUWI658QTq3a3kQL
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1fIabyDsMHzYnpOR1AUWI658QTq3a3kQL
# To: /content/datapreprocessing_new.xlsx
# 100% 1.05M/1.05M [00:00<00:00, 8.45MB/s]

# %%
import pandas as pd
data = pd.read_excel('datapreprocessing_new.xlsx')
data.columns
# Out:
# Index(['Unnamed: 0', 'mssv', 'namsinh', 'gioitinh', 'noisinh', 'lopsh', 'khoa',
#        'hedt', 'khoahoc', 'chuyennganh2', 'dien_tt', 'mamh', 'diem_hk1',
#        'diem_hk2', 'diem_hk3', 'diem_hk4', 'diem_hk5', 'diem_hk6', 'diem_hk7',
#        'diem_hk8', 'drl_hk1', 'drl_hk2', 'drl_hk3', 'drl_hk4', 'drl_hk5',
#        'drl_hk6', 'drl_hk7', 'loaixn', 'tongdiem_av', 'trangthai_av',
#        'sl_giam', 'xlhv', 'dtb_toankhoa', 'dtb_tichluy', 'sotc_tichluy',
#        'label'],
#       dtype='object')

# %%
# # file data trước khi add bảng diem_Thu
# import gdown
# !gdown 1rhTSl9xVdOw9f43gxjLetYszwKWWa3Fy
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1rhTSl9xVdOw9f43gxjLetYszwKWWa3Fy
# To: /content/datapreprocessing.xlsx
# 100% 398k/398k [00:00<00:00, 107MB/s]

# %%
# import pandas as pd
# data = pd.read_excel('datapreprocessing.xlsx')
# data.columns
# Out:
# Index(['Unnamed: 0', 'mssv', 'namsinh', 'gioitinh', 'noisinh', 'lopsh', 'khoa',
#        'hedt', 'khoahoc', 'chuyennganh2', 'dien_tt', 'mamh', 'diem_hk1',
#        'diem_hk2', 'diem_hk3', 'diem_hk4', 'diem_hk5', 'diem_hk6', 'diem_hk7',
#        'diem_hk8', 'drl_hk1', 'drl_hk2', 'drl_hk3', 'drl_hk4', 'drl_hk5',
#        'drl_hk6', 'drl_hk7', 'loaixn', 'tongdiem_av', 'trangthai_av',
#        'sl_giam', 'xlhv', 'dtb_toankhoa', 'dtb_tichluy', 'sotc_tichluy',
#        'label'],
#       dtype='object')

# %%
data = data.drop(columns = ["Unnamed: 0", "mssv"])
data
# Out:
#       namsinh  gioitinh     noisinh           lopsh            khoa  hedt  \
# 0        1995         1      TP.HCM        KTPM0001            CNPM  CQUI
# 1        1995         1   Đồng Tháp        HTTT0001            HTTT  CTTT
# 2        1995         1      TP.HCM        HTTT0001            HTTT  CTTT
# 3        1995         0     Hà Tĩnh        KTPM0001            CNPM  CQUI
# 4        1995         1  Quảng Ngãi        HTTT0001            HTTT  CQUI
# ...       ...       ...         ...             ...             ...   ...
# 6284     1988         1      TP.HCM  Khong cung cap  Khong cung cap  CQUI
# 6285     1988         1      TP.HCM  Khong cung cap  Khong cung cap  CQUI
# 6286     1988         1      TP.HCM  Khong cung cap  Khong cung cap  CQUI
# 6287     1988         1      TP.HCM  Khong cung cap  Khong cung cap  CQUI
# 6288     1988         1      TP.HCM  Khong cung cap  Khong cung cap  CQUI
#
#       khoahoc    chuyennganh2 dien_tt   mamh  ...  drl_hk7  loaixn  \
# 0           8         D480103       B  AVSC1  ...       73   TOEIC
# 1           8         D480104       B  AVSC1  ...       83   TOEIC
# 2           8         D480104       B  AVSC1  ...       65   TOEIC
# 3           8         D480103       B  AVSC1  ...       87   TOEIC
# 4           8       D52480104       B  AVSC1  ...       73   TOEIC
# ...       ...             ...     ...    ...  ...      ...     ...
# 6284        1  Khong cung cap       B  AVSC1  ...       77   TOEIC
# 6285        1  Khong cung cap       B  AVSC1  ...       77   TOEIC
# 6286        1  Khong cung cap       B  AVSC1  ...       77   TOEIC
# 6287        1  Khong cung cap       B  AVSC1  ...       77   TOEIC
# 6288        1  Khong cung cap       B  AVSC1  ...       77   TOEIC
#
#       tongdiem_av  trangthai_av  sl_giam  xlhv  dtb_toankhoa  dtb_tichluy  \
# 0           990.0             1        0     0          7.15         7.15
# 1           990.0             1        0     1          8.02         8.02
# 2           990.0             1        0     0          7.14         7.14
# 3           990.0             1        0     0          7.86         7.86
# 4           990.0             1        0     0          6.31         6.31
# ...           ...           ...      ...   ...           ...          ...
# 6284        990.0             1        0     0          6.72         6.72
# 6285        990.0             1        0     0          6.16         6.16
# 6286        990.0             1        0     0          3.81         3.81
# 6287        990.0             1        0     0          6.42         6.42
# 6288        990.0             1        0     0          6.03         6.03
#
#       sotc_tichluy  label
# 0              155      1
# 1              140      1
# 2              140      1
# 3              155      1
# 4              154      1
# ...            ...    ...
# 6284           171      1
# 6285           174      1
# 6286           172      1
# 6287           169      1
# 6288           166      1
#
# [6289 rows x 34 columns]

# %% [markdown]
# # Split Train Test Data

# %%
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# %%
X = data.iloc[:,:-1]
y = data.iloc[:,-1]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
print('Train: ', X_train.shape)
print('Test: ', X_test.shape)
X_train.columns
# Out:
# Train:  (4213, 33)
# Test:  (2076, 33)
# Index(['namsinh', 'gioitinh', 'noisinh', 'lopsh', 'khoa', 'hedt', 'khoahoc',
#        'chuyennganh2', 'dien_tt', 'mamh', 'diem_hk1', 'diem_hk2', 'diem_hk3',
#        'diem_hk4', 'diem_hk5', 'diem_hk6', 'diem_hk7', 'diem_hk8', 'drl_hk1',
#        'drl_hk2', 'drl_hk3', 'drl_hk4', 'drl_hk5', 'drl_hk6', 'drl_hk7',
#        'loaixn', 'tongdiem_av', 'trangthai_av', 'sl_giam', 'xlhv',
#        'dtb_toankhoa', 'dtb_tichluy', 'sotc_tichluy'],
#       dtype='object')

# %% [markdown]
# #Model

# %%
# import
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score, confusion_matrix, precision_score, recall_score, f1_score
import pandas as pd
from matplotlib import pyplot as plt

# %%
# encoder and normalize data
def norm(train, test):
  pd.options.mode.chained_assignment = None 
  # Encode categorical features
  label_encoder = LabelEncoder()
  X_data_list = [train, test]
  for X_data in X_data_list:
    for column in X_data.columns:
        if X_data[column].dtype == 'object' or X_data[column].dtype == 'string':
            X_data[column] = label_encoder.fit_transform(X_data[column])

  # Standardize features
  scaler = StandardScaler()
  train = scaler.fit_transform(train)
  test = scaler.transform(test)

  return train, test

# %%
# list of model
model_list = [
    LogisticRegression(),
    DecisionTreeClassifier(),
    RandomForestClassifier(),
    SVC(),
    KNeighborsClassifier(),
    GaussianNB()
  ]

def train_and_test(x_train, x_test, y_train, y_test, models):
  # create dataframe with eval
  eval = pd.DataFrame(columns = ['Model','Accuracy','Precision','Recall','F1-score'])
  # Train and evaluate models
  for model in models:
    model.fit(x_train, y_train)
    y_pred = model.predict(x_test)

    # Compute performance metrics
    acc = accuracy_score(y_test, y_pred)
    prec = precision_score(y_test, y_pred, average = 'macro')
    recall = recall_score(y_test, y_pred, average = 'macro')
    f1 = f1_score(y_test, y_pred, average = 'macro')
    
    # print result
    print(f"{type(model).__name__}")
    print(f"├── Accuracy: {acc:.5f}")
    print(f"├── Precision: {prec:.5f}")
    print(f"├── Recall: {recall:.5f}")
    print(f"└── F1 Score: {f1:.5f}")
    print("└── Confusion matrix:", confusion_matrix(y_test, y_pred))

    eval.loc[len(eval.index)] = [type(model).__name__,acc,prec,recall,f1] 
  return eval

# %%
# plot result as bar
def draw_chart(df):
  plt.rcParams["figure.figsize"] = [14, 6]
  plt.rcParams["figure.autolayout"] = True
  colors = plt.cm.Set2(range(len(df)))
  ax = df.plot.bar(x = df.columns[0], y = ['Accuracy', 'Precision', 'Recall', 'F1-score'], rot=0, color = colors)
  # for p in ax.patches:
  #       ax.annotate(str(p.get_height()), (p.get_x() + p.get_width() / 2, p.get_height()), ha='center', va='bottom')
  plt.legend(bbox_to_anchor=(1, 1))
  plt.title('Performance Metrics')
  plt.show()

# %% [markdown]
# # Chia dataset thành các tập data nhỏ theo từng học kỳ

# %% [markdown]
# ## - Nhóm 1: sinh viên mới vào trường
# ```
# 'namsinh', 'gioitinh', 'noisinh', 'lopsh', 'khoa', 'hedt', 'khoahoc', 'chuyennganh2', 'dien_tt', 'mamh'
# ```

# %%
# lấy các cột phù hợp
cols = ['namsinh', 'gioitinh', 'noisinh', 'lopsh', 'khoa', 'hedt', 'khoahoc', 'chuyennganh2', 'dien_tt', 'mamh']
X_train_1 = X_train[cols]
X_test_1 = X_test[cols]
# encoder
X_train_1, X_test_1 = norm(X_train_1, X_test_1)
# train and test
result_1 = train_and_test(X_train_1, X_test_1, y_train, y_test, model_list)
# Out:
# LogisticRegression
# ├── Accuracy: 0.86850
# ├── Precision: 0.79466
# ├── Recall: 0.55267
# └── F1 Score: 0.56155
# └── Confusion matrix: [[  33  260]
#  [  13 1770]]
# DecisionTreeClassifier
# ├── Accuracy: 0.84971
# ├── Precision: 0.65206
# ├── Recall: 0.57311
# └── F1 Score: 0.58851
# └── Confusion matrix: [[  55  238]
#  [  74 1709]]
# RandomForestClassifier
# ├── Accuracy: 0.87765
# ├── Precision: 0.84954
# ├── Recall: 0.58224
# └── F1 Score: 0.60780
# └── Confusion matrix: [[  50  243]
#  [  11 1772]]
# SVC
# ├── Accuracy: 0.87524
# ├── Precision: 0.86495
# ├── Recall: 0.56800
# └── F1 Score: 0.58625
# └── Confusion matrix: [[  41  252]
#  [   7 1776]]
# KNeighborsClassifier
# ├── Accuracy: 0.78083
# ├── Precision: 0.56646
# ├── Recall: 0.57293
# └── F1 Score: 0.56923
# └── Confusion matrix: [[  83  210]
#  [ 245 1538]]
# GaussianNB
# ├── Accuracy: 0.81358
# ├── Precision: 0.58797
# ├── Recall: 0.57204
# └── F1 Score: 0.57808
# └── Confusion matrix: [[  69  224]
#  [ 163 1620]]

# %%
result_1
# Out:
#                     Model  Accuracy  Precision    Recall  F1-score
# 0      LogisticRegression  0.868497   0.794656  0.552668  0.561547
# 1  DecisionTreeClassifier  0.849711   0.652059  0.573105  0.588509
# 2  RandomForestClassifier  0.877649   0.849538  0.582240  0.607804
# 3                     SVC  0.875241   0.864953  0.568003  0.586254
# 4    KNeighborsClassifier  0.780829   0.566456  0.572934  0.569226
# 5              GaussianNB  0.813584   0.587969  0.572038  0.578079

# %%
print(result_1['Recall'].values)
print(result_1['F1-score'].values)
draw_chart(result_1)
# Out:
# [0.55266845 0.57310511 0.58223954 0.56800289 0.57293379 0.57203796]
# [0.56154655 0.5885087  0.60780429 0.58625402 0.56922605 0.5780787 ]

# %% [markdown]
# ## - Nhóm 2: sinh viên có kq hk1
# ```
# 'namsinh', 'gioitinh', 'noisinh', 'lopsh', 'khoa', 'hedt', 'khoahoc',
# 'chuyennganh2', 'dien_tt', 'mamh', 'diem_hk1', 'drl_hk1'
# ```

# %%
# lấy các cột phù hợp
cols = ['namsinh', 'gioitinh', 'noisinh', 'lopsh', 'khoa', 'hedt', 'khoahoc', 
'chuyennganh2', 'dien_tt', 'mamh', 'diem_hk1', 'drl_hk1']
X_train_2 = X_train[cols]
X_test_2 = X_test[cols]
# encoder
X_train_2, X_test_2 = norm(X_train_2, X_test_2)
# train and test
result_2 = train_and_test(X_train_2, X_test_2, y_train, y_test, model_list)
# Out:
# LogisticRegression
# ├── Accuracy: 0.90655
# ├── Precision: 0.85788
# ├── Recall: 0.71600
# └── F1 Score: 0.76195
# └── Confusion matrix: [[ 132  161]
#  [  33 1750]]
# DecisionTreeClassifier
# ├── Accuracy: 0.86561
# ├── Precision: 0.72387
# ├── Recall: 0.73210
# └── F1 Score: 0.72785
# └── Confusion matrix: [[ 160  133]
#  [ 146 1637]]
# RandomForestClassifier
# ├── Accuracy: 0.91137
# ├── Precision: 0.87087
# ├── Recall: 0.72879
# └── F1 Score: 0.77593
# └── Confusion matrix: [[ 139  154]
#  [  30 1753]]
# SVC
# ├── Accuracy: 0.90992
# ├── Precision: 0.90322
# ├── Recall: 0.70085
# └── F1 Score: 0.75593
# └── Confusion matrix: [[ 120  173]
#  [  14 1769]]
# KNeighborsClassifier
# ├── Accuracy: 0.90125
# ├── Precision: 0.83510
# ├── Recall: 0.71007
# └── F1 Score: 0.75177
# └── Confusion matrix: [[ 130  163]
#  [  42 1741]]
# GaussianNB
# ├── Accuracy: 0.85212
# ├── Precision: 0.69517
# ├── Recall: 0.69572
# └── F1 Score: 0.69544
# └── Confusion matrix: [[ 140  153]
#  [ 154 1629]]

# %%
result_2
# print(result_2['Accuracy'].values)
# print(result_2['Precision'].values)
# print(result_2['Recall'].values)
# print(result_2['F1-score'].values)
# draw_chart(result_2)
# Out:
#                     Model  Accuracy  Precision    Recall  F1-score
# 0      LogisticRegression  0.906551   0.857875  0.716002  0.761951
# 1  DecisionTreeClassifier  0.865607   0.723867  0.732095  0.727849
# 2  RandomForestClassifier  0.911368   0.870865  0.728789  0.775934
# 3                     SVC  0.909923   0.903219  0.700852  0.755930
# 4    KNeighborsClassifier  0.901252   0.835102  0.710065  0.751770
# 5              GaussianNB  0.852119   0.695166  0.695722  0.695443

# %% [markdown]
# ## - Nhóm 3: sinh viên có kq hk2
# ```
# 'namsinh', 'gioitinh', 'noisinh', 'lopsh', 'khoa', 'hedt', 'khoahoc',
# 'chuyennganh2', 'dien_tt', 'mamh', 'diem_hk1', 'drl_hk1', 'diem_hk2', 'drl_hk2'
# ```

# %%
# lấy các cột phù hợp
cols = ['namsinh', 'gioitinh', 'noisinh', 'lopsh', 'khoa', 'hedt', 'khoahoc', 
'chuyennganh2', 'dien_tt', 'mamh', 'diem_hk1', 'drl_hk1', 'diem_hk2', 'drl_hk2']
X_train_3 = X_train[cols]
X_test_3 = X_test[cols]
# encoder
X_train_3, X_test_3 = norm(X_train_3, X_test_3)
# train and test
result_3 = train_and_test(X_train_3, X_test_3, y_train, y_test, model_list)
# Out:
# LogisticRegression
# ├── Accuracy: 0.94509
# ├── Precision: 0.92431
# ├── Recall: 0.83826
# └── F1 Score: 0.87428
# └── Confusion matrix: [[ 202   91]
#  [  23 1760]]
# DecisionTreeClassifier
# ├── Accuracy: 0.91522
# ├── Precision: 0.82603
# ├── Recall: 0.82230
# └── F1 Score: 0.82415
# └── Confusion matrix: [[ 203   90]
#  [  86 1697]]
# RandomForestClassifier
# ├── Accuracy: 0.95328
# ├── Precision: 0.94634
# ├── Recall: 0.85444
# └── F1 Score: 0.89285
# └── Confusion matrix: [[ 210   83]
#  [  14 1769]]
# SVC
# ├── Accuracy: 0.94653
# ├── Precision: 0.94068
# ├── Recall: 0.83055
# └── F1 Score: 0.87445
# └── Confusion matrix: [[ 196   97]
#  [  14 1769]]
# KNeighborsClassifier
# ├── Accuracy: 0.94123
# ├── Precision: 0.92696
# ├── Recall: 0.81890
# └── F1 Score: 0.86177
# └── Confusion matrix: [[ 190  103]
#  [  19 1764]]
# GaussianNB
# ├── Accuracy: 0.90559
# ├── Precision: 0.80353
# ├── Recall: 0.81384
# └── F1 Score: 0.80855
# └── Confusion matrix: [[ 201   92]
#  [ 104 1679]]

# %%
result_3
# Out:
#                     Model  Accuracy  Precision    Recall  F1-score
# 0      LogisticRegression  0.945087   0.924308  0.838260  0.874276
# 1  DecisionTreeClassifier  0.915222   0.826029  0.822300  0.824147
# 2  RandomForestClassifier  0.953276   0.946342  0.854436  0.892847
# 3                     SVC  0.946532   0.940675  0.830545  0.874452
# 4    KNeighborsClassifier  0.941233   0.926961  0.818904  0.861774
# 5              GaussianNB  0.905588   0.803534  0.813839  0.808546

# %%
print(result_3)
print(result_3['Accuracy'].values)
print(result_3['Precision'].values)
print(result_3['Recall'].values)
print(result_3['F1-score'].values)
draw_chart(result_3)
# Out:
#                     Model  Accuracy  Precision    Recall  F1-score
# 0      LogisticRegression  0.945087   0.924308  0.838260  0.874276
# 1  DecisionTreeClassifier  0.915222   0.826029  0.822300  0.824147
# 2  RandomForestClassifier  0.953276   0.946342  0.854436  0.892847
# 3                     SVC  0.946532   0.940675  0.830545  0.874452
# 4    KNeighborsClassifier  0.941233   0.926961  0.818904  0.861774
# 5              GaussianNB  0.905588   0.803534  0.813839  0.808546
# [0.94508671 0.91522158 0.95327553 0.94653179 0.94123314 0.90558767]
# [0.92430758 0.8260292  0.94634179 0.94067524 0.92696109 0.80353417]
# [0.83826009 0.82229972 0.85443581 0.83054502 0.81890398 0.81383908]
# [0.87427619 0.82414739 0.89284705 0.87445238 0.86177373 0.80854584]

# %% [markdown]
# ## - Nhóm 4: sinh viên có kq hk3
# ```
# 'namsinh', 'gioitinh', 'noisinh', 'lopsh', 'khoa', 'hedt', 'khoahoc',
# 'chuyennganh2', 'dien_tt', 'mamh', 'diem_hk1', 'drl_hk1', 'diem_hk2',
# 'drl_hk2', 'diem_hk3', 'drl_hk3'
# ```

# %%
# lấy các cột phù hợp
cols = ['namsinh', 'gioitinh', 'noisinh', 'lopsh', 'khoa', 'hedt', 'khoahoc', 
'chuyennganh2', 'dien_tt', 'mamh', 'diem_hk1', 'drl_hk1', 'diem_hk2', 
'drl_hk2', 'diem_hk3', 'drl_hk3']
X_train_4 = X_train[cols]
X_test_4 = X_test[cols]
# encoder
X_train_4, X_test_4 = norm(X_train_4, X_test_4)
# train and test
result_4 = train_and_test(X_train_4, X_test_4, y_train, y_test, model_list)
# Out:
# LogisticRegression
# ├── Accuracy: 0.95954
# ├── Precision: 0.93815
# ├── Recall: 0.88945
# └── F1 Score: 0.91170
# └── Confusion matrix: [[ 232   61]
#  [  23 1760]]
# DecisionTreeClassifier
# ├── Accuracy: 0.94653
# ├── Precision: 0.89524
# ├── Recall: 0.88046
# └── F1 Score: 0.88763
# └── Confusion matrix: [[ 231   62]
#  [  49 1734]]
# RandomForestClassifier
# ├── Accuracy: 0.96724
# ├── Precision: 0.95315
# ├── Recall: 0.90820
# └── F1 Score: 0.92896
# └── Confusion matrix: [[ 242   51]
#  [  17 1766]]
# SVC
# ├── Accuracy: 0.96484
# ├── Precision: 0.95412
# ├── Recall: 0.89682
# └── F1 Score: 0.92267
# └── Confusion matrix: [[ 235   58]
#  [  15 1768]]
# KNeighborsClassifier
# ├── Accuracy: 0.96002
# ├── Precision: 0.96203
# ├── Recall: 0.86977
# └── F1 Score: 0.90862
# └── Confusion matrix: [[ 218   75]
#  [   8 1775]]
# GaussianNB
# ├── Accuracy: 0.93304
# ├── Precision: 0.85587
# ├── Recall: 0.87688
# └── F1 Score: 0.86590
# └── Confusion matrix: [[ 234   59]
#  [  80 1703]]

# %%
result_4
# Out:
#                     Model  Accuracy  Precision    Recall  F1-score
# 0      LogisticRegression  0.959538   0.938153  0.889455  0.911704
# 1  DecisionTreeClassifier  0.946532   0.895239  0.880457  0.887634
# 2  RandomForestClassifier  0.967245   0.953147  0.908202  0.928961
# 3                     SVC  0.964836   0.954118  0.896817  0.922667
# 4    KNeighborsClassifier  0.960019   0.962031  0.869770  0.908615
# 5              GaussianNB  0.933044   0.855869  0.876883  0.865897

# %%
print(result_4)
print(result_4['Accuracy'].values)
print(result_4['Precision'].values)
print(result_4['Recall'].values)
print(result_4['F1-score'].values)
draw_chart(result_4)
# Out:
#                     Model  Accuracy  Precision    Recall  F1-score
# 0      LogisticRegression  0.959538   0.938153  0.889455  0.911704
# 1  DecisionTreeClassifier  0.946532   0.895239  0.880457  0.887634
# 2  RandomForestClassifier  0.967245   0.953147  0.908202  0.928961
# 3                     SVC  0.964836   0.954118  0.896817  0.922667
# 4    KNeighborsClassifier  0.960019   0.962031  0.869770  0.908615
# 5              GaussianNB  0.933044   0.855869  0.876883  0.865897
# [0.95953757 0.94653179 0.9672447  0.96483622 0.96001927 0.93304432]
# [0.93815292 0.89523942 0.95314735 0.95411829 0.96203061 0.85586913]
# [0.88945463 0.88045707 0.90820204 0.8968175  0.86977024 0.87688331]
# [0.91170395 0.88763424 0.92896135 0.92266724 0.90861547 0.86589739]

# %% [markdown]
# ## - Nhóm 5: sinh viên có kq hk4
# ```
# 'namsinh', 'gioitinh', 'noisinh', 'lopsh', 'khoa', 'hedt', 'khoahoc',
# 'chuyennganh2', 'dien_tt', 'mamh', 'diem_hk1', 'drl_hk1', 'diem_hk2',
# 'drl_hk2', 'diem_hk3', 'drl_hk3', 'diem_hk4', 'drl_hk4'
# ```

# %%
# lấy các cột phù hợp
cols = ['namsinh', 'gioitinh', 'noisinh', 'lopsh', 'khoa', 'hedt', 'khoahoc', 
'chuyennganh2', 'dien_tt', 'mamh', 'diem_hk1', 'drl_hk1', 'diem_hk2', 
'drl_hk2', 'diem_hk3', 'drl_hk3', 'diem_hk4', 'drl_hk4']
X_train_5 = X_train[cols]
X_test_5 = X_test[cols]
# encoder
X_train_5, X_test_5 = norm(X_train_5, X_test_5)
# train and test
result_5 = train_and_test(X_train_5, X_test_5, y_train, y_test, model_list)
# Out:
# LogisticRegression
# ├── Accuracy: 0.97206
# ├── Precision: 0.95309
# ├── Recall: 0.92955
# └── F1 Score: 0.94085
# └── Confusion matrix: [[ 255   38]
#  [  20 1763]]
# DecisionTreeClassifier
# ├── Accuracy: 0.96387
# ├── Precision: 0.93239
# ├── Recall: 0.91622
# └── F1 Score: 0.92408
# └── Confusion matrix: [[ 249   44]
#  [  31 1752]]
# RandomForestClassifier
# ├── Accuracy: 0.97495
# ├── Precision: 0.97079
# ├── Recall: 0.92410
# └── F1 Score: 0.94568
# └── Confusion matrix: [[ 250   43]
#  [   9 1774]]
# SVC
# ├── Accuracy: 0.97254
# ├── Precision: 0.96756
# ├── Recall: 0.91699
# └── F1 Score: 0.94018
# └── Confusion matrix: [[ 246   47]
#  [  10 1773]]
# KNeighborsClassifier
# ├── Accuracy: 0.96484
# ├── Precision: 0.96713
# ├── Recall: 0.88541
# └── F1 Score: 0.92067
# └── Confusion matrix: [[ 227   66]
#  [   7 1776]]
# GaussianNB
# ├── Accuracy: 0.95520
# ├── Precision: 0.90456
# ├── Recall: 0.91260
# └── F1 Score: 0.90852
# └── Confusion matrix: [[ 250   43]
#  [  50 1733]]

# %%
result_5
# Out:
#                     Model  Accuracy  Precision    Recall  F1-score
# 0      LogisticRegression  0.972062   0.953087  0.929545  0.940852
# 1  DecisionTreeClassifier  0.963873   0.932393  0.916221  0.924077
# 2  RandomForestClassifier  0.974952   0.970793  0.924097  0.945676
# 3                     SVC  0.972543   0.967557  0.916991  0.940177
# 4    KNeighborsClassifier  0.964836   0.967127  0.885409  0.920671
# 5              GaussianNB  0.955202   0.904561  0.912600  0.908520

# %%
print(result_5)
draw_chart(result_5)
# Out:
#                     Model  Accuracy  Precision    Recall  F1-score
# 0      LogisticRegression  0.972062   0.953087  0.929545  0.940852
# 1  DecisionTreeClassifier  0.963873   0.932393  0.916221  0.924077
# 2  RandomForestClassifier  0.974952   0.970793  0.924097  0.945676
# 3                     SVC  0.972543   0.967557  0.916991  0.940177
# 4    KNeighborsClassifier  0.964836   0.967127  0.885409  0.920671
# 5              GaussianNB  0.955202   0.904561  0.912600  0.908520

# %% [markdown]
# ## - Nhóm 6: sinh viên có kq hk5
# ```
# 'namsinh', 'gioitinh', 'noisinh', 'lopsh', 'khoa', 'hedt', 'khoahoc',
# 'chuyennganh2', 'dien_tt', 'mamh', 'diem_hk1', 'drl_hk1', 'diem_hk2',
# 'drl_hk2', 'diem_hk3', 'drl_hk3', 'diem_hk4', 'drl_hk4', 'diem_hk5', 'drl_hk5'
# ```

# %%
# lấy các cột phù hợp
cols = ['namsinh', 'gioitinh', 'noisinh', 'lopsh', 'khoa', 'hedt', 'khoahoc', 
'chuyennganh2', 'dien_tt', 'mamh', 'diem_hk1', 'drl_hk1', 'diem_hk2', 
'drl_hk2', 'diem_hk3', 'drl_hk3', 'diem_hk4', 'drl_hk4', 'diem_hk5', 'drl_hk5']
X_train_6 = X_train[cols]
X_test_6 = X_test[cols]
# encoder
X_train_6, X_test_6 = norm(X_train_6, X_test_6)
# train and test
result_6 = train_and_test(X_train_6, X_test_6, y_train, y_test, model_list)
# Out:
# LogisticRegression
# ├── Accuracy: 0.97062
# ├── Precision: 0.94684
# ├── Recall: 0.93013
# └── F1 Score: 0.93825
# └── Confusion matrix: [[ 256   37]
#  [  24 1759]]
# DecisionTreeClassifier
# ├── Accuracy: 0.96339
# ├── Precision: 0.92254
# ├── Recall: 0.92735
# └── F1 Score: 0.92493
# └── Confusion matrix: [[ 257   36]
#  [  40 1743]]
# RandomForestClassifier
# ├── Accuracy: 0.97495
# ├── Precision: 0.96631
# ├── Recall: 0.92838
# └── F1 Score: 0.94617
# └── Confusion matrix: [[ 253   40]
#  [  12 1771]]
# SVC
# ├── Accuracy: 0.97303
# ├── Precision: 0.96058
# ├── Recall: 0.92583
# └── F1 Score: 0.94220
# └── Confusion matrix: [[ 252   41]
#  [  15 1768]]
# KNeighborsClassifier
# ├── Accuracy: 0.96917
# ├── Precision: 0.97348
# ├── Recall: 0.89792
# └── F1 Score: 0.93101
# └── Confusion matrix: [[ 234   59]
#  [   5 1778]]
# GaussianNB
# ├── Accuracy: 0.95906
# ├── Precision: 0.90652
# ├── Recall: 0.93053
# └── F1 Score: 0.91799
# └── Confusion matrix: [[ 261   32]
#  [  53 1730]]

# %%
result_6
# Out:
#                     Model  Accuracy  Precision    Recall  F1-score
# 0      LogisticRegression  0.970617   0.946842  0.930130  0.938249
# 1  DecisionTreeClassifier  0.963391   0.922542  0.927350  0.924925
# 2  RandomForestClassifier  0.974952   0.966315  0.928375  0.946171
# 3                     SVC  0.973025   0.960578  0.925828  0.942205
# 4    KNeighborsClassifier  0.969171   0.973481  0.897915  0.931010
# 5              GaussianNB  0.959056   0.906525  0.930530  0.917995

# %%
print(result_6)
draw_chart(result_6)
# Out:
#                     Model  Accuracy  Precision    Recall  F1-score
# 0      LogisticRegression  0.970617   0.946842  0.930130  0.938249
# 1  DecisionTreeClassifier  0.963391   0.922542  0.927350  0.924925
# 2  RandomForestClassifier  0.974952   0.966315  0.928375  0.946171
# 3                     SVC  0.973025   0.960578  0.925828  0.942205
# 4    KNeighborsClassifier  0.969171   0.973481  0.897915  0.931010
# 5              GaussianNB  0.959056   0.906525  0.930530  0.917995

# %% [markdown]
# ## - Nhóm 7: sinh viên có kq hk6
# ```
# 'namsinh', 'gioitinh', 'noisinh', 'lopsh', 'khoa', 'hedt', 'khoahoc',
# 'chuyennganh2', 'dien_tt', 'mamh', 'diem_hk1', 'drl_hk1', 'diem_hk2',
# 'drl_hk2', 'diem_hk3', 'drl_hk3', 'diem_hk4', 'drl_hk4', 'diem_hk5',
# 'drl_hk5', 'diem_hk6', 'drl_hk6'
# ```

# %%
# lấy các cột phù hợp
cols = ['namsinh', 'gioitinh', 'noisinh', 'lopsh', 'khoa', 'hedt', 'khoahoc', 
'chuyennganh2', 'dien_tt', 'mamh', 'diem_hk1', 'drl_hk1', 'diem_hk2', 
'drl_hk2', 'diem_hk3', 'drl_hk3', 'diem_hk4', 'drl_hk4', 'diem_hk5', 
'drl_hk5', 'diem_hk6', 'drl_hk6']
X_train_7 = X_train[cols]
X_test_7 = X_test[cols]
# encoder
X_train_7, X_test_7 = norm(X_train_7, X_test_7)
# train and test
result_7 = train_and_test(X_train_7, X_test_7, y_train, y_test, model_list)
# Out:
# LogisticRegression
# ├── Accuracy: 0.97543
# ├── Precision: 0.95845
# ├── Recall: 0.93864
# └── F1 Score: 0.94822
# └── Confusion matrix: [[ 260   33]
#  [  18 1765]]
# DecisionTreeClassifier
# ├── Accuracy: 0.97062
# ├── Precision: 0.94564
# ├── Recall: 0.93156
# └── F1 Score: 0.93843
# └── Confusion matrix: [[ 257   36]
#  [  25 1758]]
# RandomForestClassifier
# ├── Accuracy: 0.97832
# ├── Precision: 0.97464
# ├── Recall: 0.93462
# └── F1 Score: 0.95335
# └── Confusion matrix: [[ 256   37]
#  [   8 1775]]
# SVC
# ├── Accuracy: 0.97351
# ├── Precision: 0.95822
# ├── Recall: 0.93039
# └── F1 Score: 0.94366
# └── Confusion matrix: [[ 255   38]
#  [  17 1766]]
# KNeighborsClassifier
# ├── Accuracy: 0.97110
# ├── Precision: 0.97471
# ├── Recall: 0.90474
# └── F1 Score: 0.93573
# └── Confusion matrix: [[ 238   55]
#  [   5 1778]]
# GaussianNB
# ├── Accuracy: 0.96435
# ├── Precision: 0.92076
# ├── Recall: 0.93504
# └── F1 Score: 0.92772
# └── Confusion matrix: [[ 262   31]
#  [  43 1740]]

# %%
result_7
# Out:
#                     Model  Accuracy  Precision    Recall  F1-score
# 0      LogisticRegression  0.975434   0.958449  0.938638  0.948221
# 1  DecisionTreeClassifier  0.970617   0.945640  0.931556  0.938430
# 2  RandomForestClassifier  0.978324   0.974639  0.934617  0.953346
# 3                     SVC  0.973507   0.958218  0.930386  0.943661
# 4    KNeighborsClassifier  0.971098   0.974709  0.904741  0.935733
# 5              GaussianNB  0.964355   0.920756  0.935041  0.927716

# %%
print(result_7)
draw_chart(result_7)
# Out:
#                     Model  Accuracy  Precision    Recall  F1-score
# 0      LogisticRegression  0.975434   0.958449  0.938638  0.948221
# 1  DecisionTreeClassifier  0.970617   0.945640  0.931556  0.938430
# 2  RandomForestClassifier  0.978324   0.974639  0.934617  0.953346
# 3                     SVC  0.973507   0.958218  0.930386  0.943661
# 4    KNeighborsClassifier  0.971098   0.974709  0.904741  0.935733
# 5              GaussianNB  0.964355   0.920756  0.935041  0.927716

# %% [markdown]
# ## - Nhóm 8: sinh viên có kq hk7
# ```
# 'namsinh', 'gioitinh', 'noisinh', 'lopsh', 'khoa', 'hedt', 'khoahoc',
# 'chuyennganh2', 'dien_tt', 'mamh', 'diem_hk1', 'drl_hk1', 'diem_hk2',
# 'drl_hk2', 'diem_hk3', 'drl_hk3', 'diem_hk4', 'drl_hk4', 'diem_hk5',
# 'drl_hk5', 'diem_hk6', 'drl_hk6', 'diem_hk7', 'drl_hk7'
# ```

# %%
# lấy các cột phù hợp
cols = ['namsinh', 'gioitinh', 'noisinh', 'lopsh', 'khoa', 'hedt', 'khoahoc', 
'chuyennganh2', 'dien_tt', 'mamh', 'diem_hk1', 'drl_hk1', 'diem_hk2', 
'drl_hk2', 'diem_hk3', 'drl_hk3', 'diem_hk4', 'drl_hk4', 'diem_hk5', 
'drl_hk5', 'diem_hk6', 'drl_hk6', 'diem_hk7', 'drl_hk7']
X_train_8 = X_train[cols]
X_test_8 = X_test[cols]
# encoder
X_train_8, X_test_8 = norm(X_train_8, X_test_8)
# train and test
result_8 = train_and_test(X_train_8, X_test_8, y_train, y_test, model_list)
# Out:
# LogisticRegression
# ├── Accuracy: 0.97977
# ├── Precision: 0.96712
# ├── Recall: 0.94829
# └── F1 Score: 0.95742
# └── Confusion matrix: [[ 265   28]
#  [  14 1769]]
# DecisionTreeClassifier
# ├── Accuracy: 0.97062
# ├── Precision: 0.94330
# ├── Recall: 0.93441
# └── F1 Score: 0.93879
# └── Confusion matrix: [[ 259   34]
#  [  27 1756]]
# RandomForestClassifier
# ├── Accuracy: 0.97881
# ├── Precision: 0.97200
# ├── Recall: 0.93918
# └── F1 Score: 0.95473
# └── Confusion matrix: [[ 259   34]
#  [  10 1773]]
# SVC
# ├── Accuracy: 0.97736
# ├── Precision: 0.96260
# ├── Recall: 0.94261
# └── F1 Score: 0.95228
# └── Confusion matrix: [[ 262   31]
#  [  16 1767]]
# KNeighborsClassifier
# ├── Accuracy: 0.97495
# ├── Precision: 0.97716
# ├── Recall: 0.91839
# └── F1 Score: 0.94500
# └── Confusion matrix: [[ 246   47]
#  [   5 1778]]
# GaussianNB
# ├── Accuracy: 0.96869
# ├── Precision: 0.92529
# ├── Recall: 0.95040
# └── F1 Score: 0.93729
# └── Confusion matrix: [[ 271   22]
#  [  43 1740]]

# %%
result_8
# Out:
#                     Model  Accuracy  Precision    Recall  F1-score
# 0      LogisticRegression  0.979769   0.967120  0.948292  0.957421
# 1  DecisionTreeClassifier  0.970617   0.943300  0.934408  0.938787
# 2  RandomForestClassifier  0.978805   0.972005  0.939175  0.954726
# 3                     SVC  0.977360   0.962602  0.942612  0.952282
# 4    KNeighborsClassifier  0.974952   0.977163  0.918393  0.945000
# 5              GaussianNB  0.968690   0.925286  0.950399  0.937290

# %%
print(result_8)
draw_chart(result_8)
# Out:
#                     Model  Accuracy  Precision    Recall  F1-score
# 0      LogisticRegression  0.979769   0.967120  0.948292  0.957421
# 1  DecisionTreeClassifier  0.970617   0.943300  0.934408  0.938787
# 2  RandomForestClassifier  0.978805   0.972005  0.939175  0.954726
# 3                     SVC  0.977360   0.962602  0.942612  0.952282
# 4    KNeighborsClassifier  0.974952   0.977163  0.918393  0.945000
# 5              GaussianNB  0.968690   0.925286  0.950399  0.937290

# %% [markdown]
# ## - Nhóm 9: sinh viên có kq hk8
# ```
# 'namsinh', 'gioitinh', 'noisinh', 'lopsh', 'khoa', 'hedt', 'khoahoc',
# 'chuyennganh2', 'dien_tt', 'mamh', 'diem_hk1', 'drl_hk1', 'diem_hk2',
# 'drl_hk2', 'diem_hk3', 'drl_hk3', 'diem_hk4', 'drl_hk4', 'diem_hk5',
# 'drl_hk5', 'diem_hk6', 'drl_hk6', 'diem_hk7', 'drl_hk7', 'diem_hk8', 'drl_hk8'
# ```

# %%
# lấy các cột phù hợp
cols = ['namsinh', 'gioitinh', 'noisinh', 'lopsh', 'khoa', 'hedt', 'khoahoc', 
'chuyennganh2', 'dien_tt', 'mamh', 'diem_hk1', 'drl_hk1', 'diem_hk2', 
'drl_hk2', 'diem_hk3', 'drl_hk3', 'diem_hk4', 'drl_hk4', 'diem_hk5', 
'drl_hk5', 'diem_hk6', 'drl_hk6', 'diem_hk7', 'drl_hk7', 'diem_hk8']
X_train_9 = X_train[cols]
X_test_9 = X_test[cols]
# encoder
X_train_9, X_test_9 = norm(X_train_9, X_test_9)
# train and test
result_9 = train_and_test(X_train_9, X_test_9, y_train, y_test, model_list)
# Out:
# LogisticRegression
# ├── Accuracy: 0.97977
# ├── Precision: 0.96712
# ├── Recall: 0.94829
# └── F1 Score: 0.95742
# └── Confusion matrix: [[ 265   28]
#  [  14 1769]]
# DecisionTreeClassifier
# ├── Accuracy: 0.97158
# ├── Precision: 0.94650
# ├── Recall: 0.93497
# └── F1 Score: 0.94062
# └── Confusion matrix: [[ 259   34]
#  [  25 1758]]
# RandomForestClassifier
# ├── Accuracy: 0.97832
# ├── Precision: 0.97166
# ├── Recall: 0.93747
# └── F1 Score: 0.95363
# └── Confusion matrix: [[ 258   35]
#  [  10 1773]]
# SVC
# ├── Accuracy: 0.97736
# ├── Precision: 0.96260
# ├── Recall: 0.94261
# └── F1 Score: 0.95228
# └── Confusion matrix: [[ 262   31]
#  [  16 1767]]
# KNeighborsClassifier
# ├── Accuracy: 0.97495
# ├── Precision: 0.97716
# ├── Recall: 0.91839
# └── F1 Score: 0.94500
# └── Confusion matrix: [[ 246   47]
#  [   5 1778]]
# GaussianNB
# ├── Accuracy: 0.96387
# ├── Precision: 0.90829
# ├── Recall: 0.95473
# └── F1 Score: 0.92955
# └── Confusion matrix: [[ 276   17]
#  [  58 1725]]

# %%
result_9
# Out:
#                     Model  Accuracy  Precision    Recall  F1-score
# 0      LogisticRegression  0.979769   0.967120  0.948292  0.957421
# 1  DecisionTreeClassifier  0.971580   0.946499  0.934969  0.940622
# 2  RandomForestClassifier  0.978324   0.971664  0.937469  0.953627
# 3                     SVC  0.977360   0.962602  0.942612  0.952282
# 4    KNeighborsClassifier  0.974952   0.977163  0.918393  0.945000
# 5              GaussianNB  0.963873   0.908294  0.954725  0.929553

# %%
print(result_9)
draw_chart(result_9)
# Out:
#                     Model  Accuracy  Precision    Recall  F1-score
# 0      LogisticRegression  0.979769   0.967120  0.948292  0.957421
# 1  DecisionTreeClassifier  0.971580   0.946499  0.934969  0.940622
# 2  RandomForestClassifier  0.978324   0.971664  0.937469  0.953627
# 3                     SVC  0.977360   0.962602  0.942612  0.952282
# 4    KNeighborsClassifier  0.974952   0.977163  0.918393  0.945000
# 5              GaussianNB  0.963873   0.908294  0.954725  0.929553

# %% [markdown]
# ## - Nhóm 10: sinh viên có kq hk8 và 1 số thông tin khác
# ```
# 'namsinh', 'gioitinh', 'noisinh', 'lopsh', 'khoa', 'hedt',
# 'khoahoc', 'chuyennganh2', 'dien_tt', 'mamh', 'diem_hk1', 'diem_hk2',
# 'diem_hk3', 'diem_hk4', 'diem_hk5', 'diem_hk6', 'diem_hk7', 'diem_hk8',
# 'drl_hk1', 'drl_hk2', 'drl_hk3', 'drl_hk4', 'drl_hk5', 'drl_hk6',
# 'drl_hk7', 'dtb_toankhoa', 'dtb_tichluy', 'sotc_tichluy'
# ```

# %%
# lấy các cột phù hợp
X_train_10 = X_train
X_test_10 = X_test
# encoder
X_train_10, X_test_10 = norm(X_train_10, X_test_10)
# train and test
result_10 = train_and_test(X_train_10, X_test_10, y_train, y_test, model_list)
# Out:
# LogisticRegression
# ├── Accuracy: 1.00000
# ├── Precision: 1.00000
# ├── Recall: 1.00000
# └── F1 Score: 1.00000
# └── Confusion matrix: [[ 293    0]
#  [   0 1783]]
# DecisionTreeClassifier
# ├── Accuracy: 0.99904
# ├── Precision: 0.99801
# ├── Recall: 0.99801
# └── F1 Score: 0.99801
# └── Confusion matrix: [[ 292    1]
#  [   1 1782]]
# RandomForestClassifier
# ├── Accuracy: 0.99952
# ├── Precision: 0.99972
# ├── Recall: 0.99829
# └── F1 Score: 0.99901
# └── Confusion matrix: [[ 292    1]
#  [   0 1783]]
# SVC
# ├── Accuracy: 1.00000
# ├── Precision: 1.00000
# ├── Recall: 1.00000
# └── F1 Score: 1.00000
# └── Confusion matrix: [[ 293    0]
#  [   0 1783]]
# KNeighborsClassifier
# ├── Accuracy: 1.00000
# ├── Precision: 1.00000
# ├── Recall: 1.00000
# └── F1 Score: 1.00000
# └── Confusion matrix: [[ 293    0]
#  [   0 1783]]
# GaussianNB
# ├── Accuracy: 0.99952
# ├── Precision: 0.99972
# ├── Recall: 0.99829
# └── F1 Score: 0.99901
# └── Confusion matrix: [[ 292    1]
#  [   0 1783]]

# %%
result_10
# Out:
#                     Model  Accuracy  Precision    Recall  F1-score
# 0      LogisticRegression  1.000000   1.000000  1.000000  1.000000
# 1  DecisionTreeClassifier  0.999037   0.998013  0.998013  0.998013
# 2  RandomForestClassifier  0.999518   0.999720  0.998294  0.999005
# 3                     SVC  1.000000   1.000000  1.000000  1.000000
# 4    KNeighborsClassifier  1.000000   1.000000  1.000000  1.000000
# 5              GaussianNB  0.999518   0.999720  0.998294  0.999005

# %%
print(result_10)
draw_chart(result_10)
# Out:
#                     Model  Accuracy  Precision    Recall  F1-score
# 0      LogisticRegression  1.000000   1.000000  1.000000  1.000000
# 1  DecisionTreeClassifier  0.999037   0.998013  0.998013  0.998013
# 2  RandomForestClassifier  0.999518   0.999720  0.998294  0.999005
# 3                     SVC  1.000000   1.000000  1.000000  1.000000
# 4    KNeighborsClassifier  1.000000   1.000000  1.000000  1.000000
# 5              GaussianNB  0.999518   0.999720  0.998294  0.999005

# %% [markdown]
# #Data Visualization

# %% [markdown]
# ## Dữ liệu train test

# %%
import seaborn as sn
data = pd.read_excel('datapreprocessing_new.xlsx')
data = data.drop(columns = ["Unnamed: 0", "mssv"])
pd.options.mode.chained_assignment = None 
# Encode categorical features
label_encoder = LabelEncoder()
for column in X.columns:
    if data[column].dtype == 'object' or data[column].dtype == 'string':
        data[column] = label_encoder.fit_transform(data[column])

# # Standardize features
# scaler = StandardScaler()
# data_norm = scaler.fit_transform(data)
plt.rcParams["figure.figsize"] = [20, 7]
plt.rcParams["figure.autolayout"] = True
corr_matrix = data.corr()
sn.heatmap(corr_matrix, annot=True, cmap = 'BrBG')
plt.show()

# %%
for column in X.columns:
  if X[column].dtype != 'object' :
    min_value = X[column].min()
    max_value = X[column].max()
    print(f"{column}: {min_value}, {max_value}")
# Out:
# namsinh: 1985, 2001
# gioitinh: 0, 1
# khoahoc: 1, 14
# diem_hk1: -1.0, 9.7
# diem_hk2: -1.0, 9.36
# diem_hk3: -1.0, 9.66
# diem_hk4: -1.0, 9.9
# diem_hk5: -1.0, 10.0
# diem_hk6: -1.0, 10.0
# diem_hk7: -1.0, 10.0
# diem_hk8: -1.0, 9.0
# drl_hk1: 0, 100
# drl_hk2: 0, 100
# drl_hk3: 0, 100
# drl_hk4: 0, 100
# drl_hk5: 0, 100
# drl_hk6: 0, 100
# drl_hk7: 0, 100
# tongdiem_av: 0.0, 990.0
# trangthai_av: 0, 1
# sl_giam: 0, 6
# xlhv: 0, 6
# dtb_toankhoa: 0.0, 9.22
# dtb_tichluy: 0.0, 9.22
# sotc_tichluy: 0, 240

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6289 entries, 0 to 6288
# Data columns (total 33 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   namsinh       6289 non-null   int64
#  1   gioitinh      6289 non-null   int64
#  2   noisinh       6289 non-null   object
#  3   lopsh         6289 non-null   object
#  4   khoa          6289 non-null   object
#  5   hedt          6289 non-null   object
#  6   khoahoc       6289 non-null   int64
#  7   chuyennganh2  6289 non-null   object
#  8   dien_tt       6289 non-null   object
#  9   mamh          6289 non-null   object
#  10  diem_hk1      6289 non-null   float64
#  11  diem_hk2      6289 non-null   float64
#  12  diem_hk3      6289 non-null   float64
#  13  diem_hk4      6289 non-null   float64
#  14  diem_hk5      6289 non-null   float64
#  15  diem_hk6      6289 non-null   float64
#  16  diem_hk7      6289 non-null   float64
#  17  diem_hk8      6289 non-null   float64
#  18  drl_hk1       6289 non-null   int64
#  19  drl_hk2       6289 non-null   int64
#  20  drl_hk3       6289 non-null   int64
#  21  drl_hk4       6289 non-null   int64
#  22  drl_hk5       6289 non-null   int64
#  23  drl_hk6       6289 non-null   int64
#  24  drl_hk7       6289 non-null   int64
#  25  loaixn        6289 non-null   object
#  26  tongdiem_av   6289 non-null   float64
#  27  trangthai_av  6289 non-null   int64
#  28  sl_giam       6289 non-null   int64
#  29  xlhv          6289 non-null   int64
#  30  dtb_toankhoa  6289 non-null   float64
#  31  dtb_tichluy   6289 non-null   float64
#  32  sotc_tichluy  6289 non-null   int64
# dtypes: float64(11), int64(14), object(8)
# memory usage: 1.6+ MB

# %%
# about X
plt.rcParams["figure.figsize"] = [4, 4]
plt.rcParams["figure.autolayout"] = True

tp = ['Train', 'Test']
n = [X_train.shape[0], X_test.shape[0]]
data_traintest = pd.DataFrame({'type': tp, 'num': n})
ax = data_traintest.plot.bar(x = 'type', y = 'num', rot=0, color = '#9900FF')
for p in ax.patches:
      ax.annotate(str(p.get_height()), (p.get_x() + p.get_width() / 2, p.get_height()), ha='center', va='bottom')
plt.legend(bbox_to_anchor=(1, 1))
plt.xlabel('Tập dữ liệu')
plt.ylabel('Số lượng')
plt.title('Biểu đồ tổng số lượng tập dữ liệu')
plt.show()

# %%
plt.rcParams["figure.figsize"] = [4, 4]
plt.rcParams["figure.autolayout"] = True
label_counts = pd.concat([pd.Series(data['label']).value_counts().reset_index(),
                         pd.Series(y_train).value_counts().reset_index(),
                         pd.Series(y_test).value_counts().reset_index()], axis = 1).T.drop_duplicates().T
label_counts.columns = ['label', 'data', 'y_train', 'y_test']
print(label_counts)
ax = label_counts.plot.bar(x = 'label', y = ['data', 'y_train', 'y_test'], rot=0, color = plt.cm.tab20_r(range(len(label_counts.columns))))
for p in ax.patches:
      ax.annotate(str(p.get_height()), (p.get_x() + p.get_width() / 2, p.get_height()), ha='center', va='bottom')
plt.legend(bbox_to_anchor=(1, 1))
plt.xlabel('Nhãn')
plt.ylabel('Số lượng')
plt.title('Biểu đồ số lượng nhãn tập dữ liệu')
plt.show()
# Out:
#    label  data  y_train  y_test
# 0      1  5367     3584    1783
# 1      0   922      629     293

# %% [markdown]
# ## Tính trung bình kết quả của từng nhóm

# %%
dataframes = [result_1,result_2,result_3,result_4,result_5,result_6,result_7,result_8,result_9,result_10]
sumary = []
for i in dataframes:
  sumary.append(i.mean())
# Tạo DataFrame tổng hợp
summary_df = pd.concat(sumary, axis=1).T
summary_df['Group'] = [i+1 for i in range(10)]
summary_df = summary_df[['Group','Accuracy', 'Precision', 'Recall', 'F1-score']]

# Hiển thị DataFrame tổng hợp
print(summary_df)
draw_chart(summary_df)
# Out:
# <ipython-input-40-0a0ad7f1ba15>:4: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sumary.append(i.mean())
# <ipython-input-40-0a0ad7f1ba15>:4: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sumary.append(i.mean())
# <ipython-input-40-0a0ad7f1ba15>:4: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sumary.append(i.mean())
# <ipython-input-40-0a0ad7f1ba15>:4: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sumary.append(i.mean())
# <ipython-input-40-0a0ad7f1ba15>:4: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sumary.append(i.mean())
# <ipython-input-40-0a0ad7f1ba15>:4: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sumary.append(i.mean())
# <ipython-input-40-0a0ad7f1ba15>:4: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sumary.append(i.mean())
# <ipython-input-40-0a0ad7f1ba15>:4: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sumary.append(i.mean())
# <ipython-input-40-0a0ad7f1ba15>:4: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sumary.append(i.mean())
# <ipython-input-40-0a0ad7f1ba15>:4: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sumary.append(i.mean())
#    Group  Accuracy  Precision    Recall  F1-score
# 0      1  0.844252   0.719272  0.570165  0.581903
# 1      2  0.891137   0.814349  0.713921  0.744813
# 2      3  0.934489   0.894642  0.829714  0.856007
# 3      4  0.955202   0.926426  0.886931  0.904247
# 4      5  0.967245   0.949253  0.914144  0.929996
# 5      6  0.968369   0.946047  0.923355  0.933426
# 6      7  0.972222   0.955402  0.929163  0.941185
# 7      8  0.975032   0.957913  0.938880  0.947584
# 8      9  0.974310   0.955557  0.939410  0.946417
# 9     10  0.999679   0.999575  0.999100  0.999337

# %%
summary_df
# Out:
#    Group  Accuracy  Precision    Recall  F1-score
# 0      1  0.844252   0.719272  0.570165  0.581903
# 1      2  0.891137   0.814349  0.713921  0.744813
# 2      3  0.934489   0.894642  0.829714  0.856007
# 3      4  0.955202   0.926426  0.886931  0.904247
# 4      5  0.967245   0.949253  0.914144  0.929996
# 5      6  0.968369   0.946047  0.923355  0.933426
# 6      7  0.972222   0.955402  0.929163  0.941185
# 7      8  0.975032   0.957913  0.938880  0.947584
# 8      9  0.974310   0.955557  0.939410  0.946417
# 9     10  0.999679   0.999575  0.999100  0.999337

# %% [markdown]
# ## So sánh từng độ đo của từng nhóm dựa trên kết quả trung bình

# %%
plt.rcParams["figure.figsize"] = [12, 7]
plt.rcParams["figure.autolayout"] = True

ax = summary_df.plot(x = 'Group', y = ['Accuracy','Precision','Recall','F1-score'], rot=0,  marker='o')

plt.legend(bbox_to_anchor=(1, 1))
plt.xticks(summary_df['Group'])
plt.title('Metrics each group')
plt.show()

# %%
# accuracy
plt.rcParams["figure.figsize"] = [20, 6]
plt.rcParams["figure.autolayout"] = True

ax = summary_df.plot.bar(x = 'Group', y = ['Accuracy'], rot=0, color = 'violet')
for p in ax.patches:
  ax.annotate(str(p.get_height()), (p.get_x() + p.get_width() / 2, p.get_height()), ha='center', va='bottom', color = 'r')

plt.legend(bbox_to_anchor=(1, 1))
plt.title('Accuracy-score')
plt.show()

# %%
# Precision
plt.rcParams["figure.figsize"] = [20, 6]
plt.rcParams["figure.autolayout"] = True

ax = summary_df.plot.bar(x = 'Group', y = ['Precision'], rot=0, color = 'violet')
for p in ax.patches:
  ax.annotate(str(p.get_height()), (p.get_x() + p.get_width() / 2, p.get_height()), ha='center', va='bottom', color = 'r')

plt.legend(bbox_to_anchor=(1, 1))
plt.title('Precision-score')
plt.show()

# %%
# Recall
plt.rcParams["figure.figsize"] = [20, 6]
plt.rcParams["figure.autolayout"] = True

ax = summary_df.plot.bar(x = 'Group', y = ['Recall'], rot=0, color = 'violet')
for p in ax.patches:
  ax.annotate(str(p.get_height()), (p.get_x() + p.get_width() / 2, p.get_height()), ha='center', va='bottom', color = 'r')

plt.legend(bbox_to_anchor=(1, 1))
plt.title('Recall-score')
plt.show()

# %%
# F1
plt.rcParams["figure.figsize"] = [20, 6]
plt.rcParams["figure.autolayout"] = True

ax = summary_df.plot.bar(x = 'Group', y = ['F1-score'], rot=0, color = 'violet')
for p in ax.patches:
  ax.annotate(str(p.get_height()), (p.get_x() + p.get_width() / 2, p.get_height()), ha='center', va='bottom', color = 'r')

plt.legend(bbox_to_anchor=(1, 1))
plt.title('F1-score')
plt.show()

# %% [markdown]
# ## Tính trung bình các kết quả của 10 nhóm

# %%
# Tạo danh sách DataFrame
dataframes = [result_1,result_2,result_3,result_4,result_5,result_6,result_7,result_8,result_9,result_10]

# Tính trung bình các giá trị của từng ô
average_df = pd.concat(dataframes).groupby('Model').mean().reset_index()

# Hiển thị DataFrame trung bình
print(average_df)
draw_chart(average_df)
# Out:
#                     Model  Accuracy  Precision    Recall  F1-score
# 0  DecisionTreeClassifier  0.941618   0.878558  0.865047  0.869299
# 1              GaussianNB  0.931503   0.850768  0.864007  0.856804
# 2    KNeighborsClassifier  0.943834   0.916019  0.849652  0.876880
# 3      LogisticRegression  0.955732   0.930761  0.869128  0.885164
# 4  RandomForestClassifier  0.959441   0.947503  0.873569  0.895810
# 5                     SVC  0.957033   0.947452  0.865465  0.886991

# %%
average_df
# Out:
#                     Model  Accuracy  Precision    Recall  F1-score
# 0  DecisionTreeClassifier  0.941618   0.878558  0.865047  0.869299
# 1              GaussianNB  0.931503   0.850768  0.864007  0.856804
# 2    KNeighborsClassifier  0.943834   0.916019  0.849652  0.876880
# 3      LogisticRegression  0.955732   0.930761  0.869128  0.885164
# 4  RandomForestClassifier  0.959441   0.947503  0.873569  0.895810
# 5                     SVC  0.957033   0.947452  0.865465  0.886991

# %% [markdown]
# ## So sánh từng độ đo của từng model dựa trên kết quả trung bình

# %%
plt.rcParams["figure.figsize"] = [12, 7]
plt.rcParams["figure.autolayout"] = True

ax = average_df.plot(x = 'Model', y = ['Accuracy','Precision','Recall','F1-score'], rot=0,  marker='o')

plt.legend(bbox_to_anchor=(1, 1))
# plt.xticks(average_df['Model'])
plt.title('Metrics each Model')
plt.show()

# %%
# accuracy
plt.rcParams["figure.figsize"] = [12, 6]
plt.rcParams["figure.autolayout"] = True

ax = average_df.plot.bar(x = 'Model', y = ['Accuracy'], rot=0, color = 'orange')
for p in ax.patches:
  ax.annotate(str(p.get_height()), (p.get_x() + p.get_width() / 2, p.get_height()), ha='center', va='bottom', color = 'r')

plt.legend(bbox_to_anchor=(1, 1))
plt.title('Accuracy-score')
plt.show()

# %%
# Precision
plt.rcParams["figure.figsize"] = [12, 6]
plt.rcParams["figure.autolayout"] = True

ax = average_df.plot.bar(x = 'Model', y = ['Precision'], rot=0, color = 'orange')
for p in ax.patches:
  ax.annotate(str(p.get_height()), (p.get_x() + p.get_width() / 2, p.get_height()), ha='center', va='bottom', color = 'r')

plt.legend(bbox_to_anchor=(1, 1))
plt.title('Precision-score')
plt.show()

# %%
# Recall
plt.rcParams["figure.figsize"] = [12, 6]
plt.rcParams["figure.autolayout"] = True

ax = average_df.plot.bar(x = 'Model', y = ['Recall'], rot=0, color = 'orange')
for p in ax.patches:
  ax.annotate(str(p.get_height()), (p.get_x() + p.get_width() / 2, p.get_height()), ha='center', va='bottom', color = 'r')

plt.legend(bbox_to_anchor=(1, 1))
plt.title('Recall-score')
plt.show()

# %%
# F1-score
plt.rcParams["figure.figsize"] = [12, 6]
plt.rcParams["figure.autolayout"] = True

ax = average_df.plot.bar(x = 'Model', y = ['F1-score'], rot=0, color = 'orange')
for p in ax.patches:
  ax.annotate(str(p.get_height()), (p.get_x() + p.get_width() / 2, p.get_height()), ha='center', va='bottom', color = 'r')

plt.legend(bbox_to_anchor=(1, 1))
plt.title('F1-score')
plt.show()
